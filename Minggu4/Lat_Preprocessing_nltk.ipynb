# %%
import re
import string
import time
from copy import deepcopy

# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset_Sentimen_Emosi.csv')

# %%
df.head()
# Out:
#                                                Tweet  Sentimen  Emosi
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0     -2
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0     -2

# %%
df = df.drop(['Emosi'], axis=1)

# %%
df
# Out:
#                                                  Tweet  Sentimen
# 0    Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1    aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2    Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3              Covid belum nyampe prigen mbak hmm hoax       0.0
# 4    Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# ..                                                 ...       ...
# 899  Seluruh negara di dunia mengalami masa sulit k...       1.0
# 900  Setelah covid dan skripsi disaster selesai, ma...       1.0
# 901  Malam ini!! Projek "BENDA BOLEH BINCANG" 9 mal...       0.0
# 902                Pontang - panting di koyak covid 19      -1.0
# 903  Masalahnya sekarang isu jangkitan covid. Alaaa...      -1.0
#
# [904 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     904 non-null    object
#  1   Sentimen  903 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.3+ KB

# %%
pip install ekphrasis
# Out:
# Requirement already satisfied: ekphrasis in c:\users\arum maulia\anaconda3\lib\site-packages (0.5.4)
# Requirement already satisfied: termcolor in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (2.4.0)
# Requirement already satisfied: tqdm in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (4.65.0)
# Requirement already satisfied: colorama in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (0.4.6)
# Requirement already satisfied: ujson in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (5.4.0)
# Requirement already satisfied: matplotlib in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (3.8.0)
# Requirement already satisfied: nltk in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (3.8.1)
# Requirement already satisfied: ftfy in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (6.2.0)
# Requirement already satisfied: numpy in c:\users\arum maulia\anaconda3\lib\site-packages (from ekphrasis) (1.26.4)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\arum maulia\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arum maulia\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: click in c:\users\arum maulia\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.1.7)
# Requirement already satisfied: joblib in c:\users\arum maulia\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\arum maulia\anaconda3\lib\site-packages (from nltk->ekphrasis) (2023.10.3)
# Requirement already satisfied: six>=1.5 in c:\users\arum maulia\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\ARUM MAULIA\anaconda3\Lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# C:\Users\ARUM MAULIA\anaconda3\Lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in
# Reading twitter - 1grams ...

# %%
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %%
i = 0
final_string = []
s = ""
for text in df['Tweet'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji_alzami(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
#
#                                               step01
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid   smg para pejab...
# 8  cegah covid   beserta jajaran polsek kuranji m...
# 9  ya allah kami memohon pada mu perkenankanlah d...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     904 non-null    object
#  1   Sentimen  903 non-null    float64
#  2   step01    904 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 21.3+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 78 to 78
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     1 non-null      object
#  1   Sentimen  1 non-null      float64
#  2   step01    1 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 32.0+ bytes

# %%
df_hapus.head(10)
# Out:
#     Tweet  Sentimen step01
# 78  covid       0.0  covid

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 902 entries, 0 to 903
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     902 non-null    object
#  1   Sentimen  902 non-null    float64
#  2   step01    902 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 28.2+ KB

# %%
df_new
# Out:
#                                                  Tweet  Sentimen  \
# 0    Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1    aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2    Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3              Covid belum nyampe prigen mbak hmm hoax       0.0
# 4    Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# ..                                                 ...       ...
# 899  Seluruh negara di dunia mengalami masa sulit k...       1.0
# 900  Setelah covid dan skripsi disaster selesai, ma...       1.0
# 901  Malam ini!! Projek "BENDA BOLEH BINCANG" 9 mal...       0.0
# 902                Pontang - panting di koyak covid 19      -1.0
# 903  Masalahnya sekarang isu jangkitan covid. Alaaa...      -1.0
#
#                                                 step01
# 0    cegah mata rantai covid   mari kita dirumah sa...
# 1    aku mohon yaallah semoga wabah covid   menghil...
# 2    pemprov papua naikkan status jadi tanggap daru...
# 3              covid belum nyampe prigen mbak hmm hoax
# 4    nyuruh orang pintar lu aja togog itu kerumunan...
# ..                                                 ...
# 899  seluruh negara di dunia mengalami masa sulit k...
# 900  setelah covid dan skripsi disaster selesai mau...
# 901  malam ini projek benda boleh bincang   malam d...
# 902                   pontang panting di koyak covid
# 903  masalahnya sekarang isu jangkitan covid alaaaa...
#
# [902 rows x 3 columns]

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid   smg para pejab...
# 8  cegah covid   beserta jajaran polsek kuranji m...
# 9  ya allah kami memohon pada mu perkenankanlah d...
#
#                                               tokens
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jumat, jumat, keempat, d...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]
# Out:
# C:\Users\ARUM MAULIA\AppData\Local\Temp\ipykernel_4348\2408214049.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\ARUM MAULIA\AppData\Local\Temp\ipykernel_4348\2408214049.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid   smg para pejab...
# 8  cegah covid   beserta jajaran polsek kuranji m...
# 9  ya allah kami memohon pada mu perkenankanlah d...
#
#                                               tokens  \
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jumat, jumat, keempat, d...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...
#
#                                         final_tokens  \
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jumat, jumat, keempat, d...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...
#
#                                               step02
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid smg para pejabat...
# 8  cegah covid beserta jajaran polsek kuranji mel...
# 9  ya allah kami memohon pada mu perkenankanlah d...

# %%
df_new.to_csv('clean_dataset.csv',sep=";")
